# %%
import pandas as pd

df = pd.read_csv('../data/imigrasi_combined_topics.csv')
df
# Out:
#                      topic              category  \
# 0                      FAQ              M-Paspor
# 1                      FAQ              M-Paspor
# 2                      FAQ              M-Paspor
# 3                      FAQ              M-Paspor
# 4                      FAQ              M-Paspor
# ...                    ...                   ...
# 1577  Regulasi UU Imigrasi  Regulasi UU Imigrasi
# 1578  Regulasi UU Imigrasi  Regulasi UU Imigrasi
# 1579  Regulasi UU Imigrasi  Regulasi UU Imigrasi
# 1580  Regulasi UU Imigrasi  Regulasi UU Imigrasi
# 1581  Regulasi UU Imigrasi  Regulasi UU Imigrasi
#
#                                                question  \
# 0     Apa yang harus saya lakukan jika aplikasi M-Pa...
# 1     Apa yang harus saya lakukan jika tidak bisa lo...
# 2     Apa yang harus saya lakukan jika tidak bisa me...
# 3     Bagaimana Cara Menutup Akun pada Aplikasi M-Pa...
# 4     Bagaimana caranya untuk mendapatkan kuota pada...
# ...

# %%
df['full_context'] = 'Question: ' + df['question'] + '; Answer: ' + df['answer'] + '; Reference: ' + df['answer_link']
df
# Out:
#                      topic              category  \
# 0                      FAQ              M-Paspor
# 1                      FAQ              M-Paspor
# 2                      FAQ              M-Paspor
# 3                      FAQ              M-Paspor
# 4                      FAQ              M-Paspor
# ...                    ...                   ...
# 1577  Regulasi UU Imigrasi  Regulasi UU Imigrasi
# 1578  Regulasi UU Imigrasi  Regulasi UU Imigrasi
# 1579  Regulasi UU Imigrasi  Regulasi UU Imigrasi
# 1580  Regulasi UU Imigrasi  Regulasi UU Imigrasi
# 1581  Regulasi UU Imigrasi  Regulasi UU Imigrasi
#
#                                                question  \
# 0     Apa yang harus saya lakukan jika aplikasi M-Pa...
# 1     Apa yang harus saya lakukan jika tidak bisa lo...
# 2     Apa yang harus saya lakukan jika tidak bisa me...
# 3     Bagaimana Cara Menutup Akun pada Aplikasi M-Pa...
# 4     Bagaimana caranya untuk mendapatkan kuota pada...
# ...

# %%
df.to_csv('../data/imigrasi_combined_topics_full_context.csv', index=False)
