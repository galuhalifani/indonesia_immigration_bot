# %%
import time
import re
import csv
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import re
from selenium.webdriver.common.by import By

# %%
base_url = 'https://www.imigrasi.go.id'
initial_url = 'https://www.imigrasi.go.id/faq/visa'

url_wni = 'https://www.imigrasi.go.id/custom/view?type=wni-category'
url_wna = 'https://www.imigrasi.go.id/custom/view?type=wna-category'
url_uu_imigrasi = 'https://www.imigrasi.go.id/uu_imigrasi'

web_urls = {
    "urls": [url_wni, url_wna],
    "topic": ["Warga Negara Indonesia", "Warga Negara Asing"],
    "classes": ["cta-box2 col-4 d-flex align-items-center justify-content-center text-decoration-none", "cta-box2 col-4 d-flex align-items-center justify-content-center text-decoration-none"]
    }

# %%
def initiate_page(link, driver):
    '''
    This function is used to open the page and instruct driver to interact with the page. 
    This function will later be called by the main function inside a loop for multiple page scraping.
    '''
    driver.get(link)

    time.sleep(2) 

    last_height = driver.execute_script("return document.body.scrollHeight")
    
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        time.sleep(2)
        new_height = driver.execute_script("return document.body.scrollHeight")
        
        if driver.find_elements(By.CLASS_NAME, "footer"):
            break

        if new_height == last_height:
            break
        last_height = new_height

    driver.execute_script("window.scrollBy(100,0)") # add side scroll

    html = driver.page_source
    soup = bs(html, 'html.parser')
    return soup

# %%
def extract_category_groups(link, driver, class_name, topic):
    soup = initiate_page(link, driver)
    categories_links = {
        'topic': [],
        'title': [],
        'link': []
    }
    link_tag = soup.find_all('a', class_=class_name)
    for link in link_tag:
        categories_links['topic'].append(topic)
        categories_links['title'].append(link.text.strip())
        categories_links['link'].append(link['href'])
    
    return categories_links

# %%
def find_links_with_classes(soup, required_classes):
    """
    Find all <a> tags that contain all required classes.
    """
    return soup.find_all(
        'a',
        class_=lambda c: c and all(rc in c for rc in required_classes)
    )

# %%
def extract_categories(link, driver):
    soup = initiate_page(link, driver)
    categories_links = {
        'title': [],
        'link': []
    }
    link_tag = find_links_with_classes(soup, ["btn-type", "text-start"])
    for link in link_tag:
        categories_links['title'].append(link.text.strip())
        categories_links['link'].append(link['href'])
    
    return categories_links

# %%
def extract_questions(title, link, driver, topic, question=None):
    soup = initiate_page(link, driver)
    qa = { 
        "topic": [],
        "category": [],
        "question": [], 
        "answer_link": [],
        "answer": []
    }
    if (topic == 'FAQ'):
        questions_list = soup.find_all('a', class_='accordion-button collapsed')

        for q in questions_list:
            answerLink = q['href']
            answer_full_link = f'{base_url}{answerLink}'

            answer_page = initiate_page(answer_full_link, driver)
            answer_div = answer_page.find(id=re.compile("^faq-content-"))

            answer = answer_div.text.strip() if answer_div else 'No answer found'
            qa["topic"].append(topic)
            qa["category"].append(title)
            qa["question"].append(q.get_text())
            qa["answer_link"].append(answer_full_link),
            qa["answer"].append(answer)
    else:
        accordions = soup.find_all('div', class_='accordion-item')

        for div in accordions:
            sub_question_header = div.find('h3', class_='accordion-header')
            sub_question = sub_question_header.text.strip()

            answer_div = div.find(id=re.compile("-content-"))
            answer = answer_div.text.strip() if answer_div else 'No answer found'

            full_question = f"{question} {sub_question}"
            qa["topic"].append(topic)
            qa["category"].append(title)
            qa["question"].append(full_question)
            qa["answer_link"].append(link),
            qa["answer"].append(answer)
    
    return qa

# %%
def clean_text_preserve_linebreaks(text):
    import re
    text = text.replace('\xa0', ' ').replace('\ufeff', '')
    text = text.replace('\t', ' ')
    text = re.sub(r'[ ]{2,}', ' ', text)
    text = re.sub(r'[ \t]*\n[ \t]*', '\n', text)
    return text.strip()

# %%
def merge_and_save_data(qa_all, driver, file_path):
    merged_qa = {
        "topic": [],
        "category": [],
        "question": [],
        "answer_link": [],
        "answer": []
    }

    for qa in qa_all:
        for key in merged_qa:
            merged_qa[key] += qa.get(key, [])

    print("#############################")
    print(merged_qa)
    driver.quit()

    df_raw = pd.DataFrame(merged_qa)
    df_raw.to_csv(file_path, index=False, encoding='utf-8-sig')
    # df_raw.to_csv('../data/raw/imigrasi_faq_raw.csv', index=False, encoding='utf-8-sig')
    return df_raw

# %% [markdown]
# SCRAPE FAQ

# %%
cat_links = ['/faq/m-paspor', '/faq/affidavit', '/faq/izin-tinggal', '/faq/kartu-perjalanan-pebisnins-apec', '/faq/paspor', '/faq/pelaporan-orang-asing', '/faq/sduwhv', '/faq/visa']
print("The following dataset is taken from:\n")

for link in cat_links:
    print(f"https://www.imigrasi.go.id{link}")
# Out:
# The following dataset is taken from:
#
# https://www.imigrasi.go.id/faq/m-paspor
# https://www.imigrasi.go.id/faq/affidavit
# https://www.imigrasi.go.id/faq/izin-tinggal
# https://www.imigrasi.go.id/faq/kartu-perjalanan-pebisnins-apec
# https://www.imigrasi.go.id/faq/paspor
# https://www.imigrasi.go.id/faq/pelaporan-orang-asing
# https://www.imigrasi.go.id/faq/sduwhv
# https://www.imigrasi.go.id/faq/visa

# %%
def start_scrape_faq():
    driver = webdriver.Chrome()

    categories_link = extract_categories(initial_url, driver)
    print(categories_link)

    qa_all = []
        
    for i, link in enumerate(categories_link['link']):
        cat_title = categories_link['title'][i]
        cat_link = f'{base_url}{link}'
        qa = extract_questions(cat_title, cat_link, driver, "FAQ")
        print(f'{len(qa["question"])} questions extracted from {cat_link}')
        qa_all.append(qa)
    
    return merge_and_save_data(qa_all, driver, '../data/raw/imigrasi_faq_raw.csv')

def clean_faq(df_raw):
    df = df_raw.copy()
    df['question'] = df['question'].apply(clean_text_preserve_linebreaks)
    df['answer'] = df['answer'].apply(clean_text_preserve_linebreaks)
    df['type'] = 'faq'
    df.head()
    df.to_csv("../data/raw/imigrasi_faq_cleaned.csv", index=False)
    print("Data cleaned and saved to imigrasi_faq_cleaned.csv")
    return df

# %%
df_faq_raw = start_scrape_faq()
df_faq_clean = clean_faq(df_faq_raw)
# Out:
# {'title': ['M-Paspor', 'Affidavit', 'Izin Tinggal', 'Kartu Perjalanan Pebisnis APEC', 'Paspor', 'Pelaporan Orang Asing', 'SDUWHV', 'Visa'], 'link': ['/faq/m-paspor', '/faq/affidavit', '/faq/izin-tinggal', '/faq/kartu-perjalanan-pebisnins-apec', '/faq/paspor', '/faq/pelaporan-orang-asing', '/faq/sduwhv', '/faq/visa']}
# 6 questions extracted from https://www.imigrasi.go.id/faq/m-paspor
# 2 questions extracted from https://www.imigrasi.go.id/faq/affidavit
# 5 questions extracted from https://www.imigrasi.go.id/faq/izin-tinggal
# 6 questions extracted from https://www.imigrasi.go.id/faq/kartu-perjalanan-pebisnins-apec
# 8 questions extracted from https://www.imigrasi.go.id/faq/paspor
# 1 questions extracted from https://www.imigrasi.go.id/faq/pelaporan-orang-asing
# 8 questions extracted from https://www.imigrasi.go.id/faq/sduwhv
# 9 questions extracted from https://www.imigrasi.go.id/faq/visa
# #############################
# {'topic': ['FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ', 'FAQ'], 'category': ['M-Paspor', 'M-Paspor', 'M-Paspor', 'M-Paspor', 'M-Paspor', 'M-Paspor', 'Affidavit', 'Affidavit', 'Izin Tinggal', 'Izin Tinggal', 'Izin Tinggal', 'Izin Tinggal', 'Izin Tinggal', 'Kartu Perjalanan Pebisnis APEC', 'Kartu Perjalanan Pebisnis APEC', 'Kartu Perjalanan Pebisnis APEC', 'Kartu Perjalanan Pebisnis APEC', 'Kartu Perjalanan Pebisnis APEC', 'Kartu Perjalanan Pebisnis APEC', 'Paspor', 'Paspor', 'Paspor', 'Paspor', 'Paspor', 'Paspor', 'Paspor', 'Paspor', 'Pelaporan Orang Asing', 'SDUWHV', 'SDUWHV', 'SDUWHV', 'SDUWHV', 'SDUWHV', 'SDUWHV', 'SDUWHV', 'SDUWHV', 'Visa', 'Visa', 'Visa', 'Visa', 'Visa', 'Visa', 'Visa', 'Visa', 'Visa'], 'question': ['\n\t\t\t\tApa yang harus saya lakukan jika aplikasi M-Paspor saya menampilkan pesan Request Timed Out?\t\t\t', '\n\t\t\t\tApa yang harus saya lakukan jika tidak bisa login ke dalam aplikasi M-Paspor?\t\t\t', '\n\t\t\t\tApa yang harus saya lakukan jika tidak bisa mengunduh surat pengantar Kantor Imigrasi?\t\t\t', '\n\t\t\t\tBagaimana Cara Menutup Akun pada Aplikasi M-Paspor Saya?\t\t\t', '\n\t\t\t\tBagaimana caranya untuk mendapatkan kuota pada aplikasi M-Paspor?\t\t\t', '\n\t\t\t\tBagaimana jika status pembayaran di M-Paspor saya tidak berubah setelah melakukan pembayaran?\t\t\t', '\n\t\t\t\tApa saja persyaratan permohonan paspor anak berkewarganegaraan ganda?\t\t\t', '\n\t\t\t\tBagaimana prosedur permohonan paspor anak berkewarganegaraan ganda?\t\t\t', '\n\t\t\t\tAlih Status dari Izin Tinggal Kunjungan (ITK) ke Izin Tinggal Terbatas (ITAS)\t\t\t', '\n\t\t\t\tAlih Status dari Izin Tinggal Terbatas (ITAS) ke Izin Tinggal Tetap (ITAP)\t\t\t', '\n\t\t\t\tApa Saja Syarat Pengajuan Izin Tinggal Tetap?\t\t\t', '\n\t\t\t\tApa Saja Syarat Pengajuan Izin Tinggal Kunjungan?\t\t\t', '\n\t\t\t\tApa Saja Syarat Pengajuan Izin Tinggal Terbatas?\t\t\t', '\n\t\t\t\tApa itu ABTC?\t\t\t', '\n\t\t\t\tBagaimana saya bisa mendapatkan ABTC?\t\t\t', '\n\t\t\t\tBerapa biaya pengurusan ABTC?\t\t\t', '\n\t\t\t\tBerapa lama waktu penyelesaian ABTC dan masa berlakunya?\t\t\t', '\n\t\t\t\tDi mana saya bisa mengajukan pengurusan ABTC?\t\t\t', '\n\t\t\t\tNegara apa saja yang menerapkan skema ABTC?\t\t\t', '\n\t\t\t\tApa syarat untuk pengurusan paspor baru atau penggantian paspor?\t\t\t', '\n\t\t\t\tApakah dokumen persyaratan paspor bisa digantikan oleh dokumen lain?\t\t\t', '\n\t\t\t\tApa yang harus saya lakukan jika dimintakan dokumen tambahan di luar persyaratan?\t\t\t', '\n\t\t\t\tBerapa biaya urus paspor saat ini?\t\t\t', '\n\t\t\t\tBagaimana prosedur untuk pengurusan paspor baru atau penggantian paspor?\t\t\t', '\n\t\t\t\tApa syarat untuk pengurusan paspor anak?\t\t\t', '\n\t\t\t\tDi Kantor Imigrasi mana saja saya bisa mengajukan e-paspor?\t\t\t', '\n\t\t\t\tApa yang harus saya lakukan jika paspor saya hilang atau rusak?\t\t\t', '\n\t\t\t\tBagaimana cara melaporkan terkait keberadaan/aktivitas orang asing?\t\t\t', '\n\t\t\t\tBagaimana cara mengajukan permohonan SDUWHV?\t\t\t', '\n\t\t\t\tApa itu Surat Dukungan Untuk Work and Holiday Visa (SDUWHV) Australia?\t\t\t', '\n\t\t\t\tBagaimana jika saya menemui kendala?\t\t\t', '\n\t\t\t\tBerkas apa saja yang perlu dipersiapkan untuk mengajukan SDUWHV Australia?\t\t\t', '\n\t\t\t\tDi mana saya dapat mengajukan permohonan Work and Holiday Visa Australia?\t\t\t', '\n\t\t\t\tKapan jadwal pembukaan pengajuan Work and Holiday Visa Australia?\t\t\t', '\n\t\t\t\tApa itu Working-Holiday Visa?\t\t\t', '\n\t\t\t\tSiapa saja yang dapat mengikuti program Work and Holiday Visa Australia?\t\t\t', '\n\t\t\t\tApa saja dokumen persyaratan untuk mengajukan E-VOA?\t\t\t', '\n\t\t\t\tApa saja dokumen persyaratan untuk mengajukan Visa Online?\t\t\t', '\n\t ...
# Data cleaned and saved to imigrasi_faq_cleaned.csv

# %% [markdown]
# SCRAPE WEB

# %%
print("The following dataset is taken from:\n")

for link in web_urls['urls']:
    print(f"https://www.imigrasi.go.id{link}")
# Out:
# The following dataset is taken from:
#
# https://www.imigrasi.go.idhttps://www.imigrasi.go.id/custom/view?type=wni-category
# https://www.imigrasi.go.idhttps://www.imigrasi.go.id/custom/view?type=wna-category

# %%
def start_scrape_web():
    driver = webdriver.Chrome()

    all_category_groups = []
    for i, url in enumerate(web_urls['urls']):
        categories_link = extract_category_groups(url, driver, web_urls['classes'][i], web_urls['topic'][i])
        all_category_groups.append(categories_link)

    # manually add UU imigrasi
    all_category_groups.append({
        'topic': ['Regulasi UU Imigrasi'],
        'title': ['Regulasi UU Imigrasi'],
        'link': ['/uu_imigrasi']
    })

    print(all_category_groups)

    qa_all = []

    for group in all_category_groups:
        for i, catLink in enumerate(group['link']):
            categories = extract_categories(f'{base_url}{catLink}', driver)
            
            for index, link in enumerate(categories['link']):
                sub_title = categories['title'][index]
                cat_title = group['title'][i]
                full_question = f'{cat_title} {sub_title}'
                cat_topic = group['topic'][i]
                cat_link = f'{base_url}{link}'
                qa = extract_questions(cat_title, cat_link, driver, cat_topic, full_question)
                print(f'{len(qa["question"])} topics extracted from {cat_link}')
                qa_all.append(qa)
    
    print(qa_all)

    return merge_and_save_data(qa_all, driver, '../data/raw/imigrasi_web_raw.csv')

def clean_faq_web(df_raw):
    df = df_raw.copy()
    df['question'] = df['question'].apply(clean_text_preserve_linebreaks)
    df['answer'] = df['answer'].apply(clean_text_preserve_linebreaks)
    df['type'] = 'web'
    df.head()
    df.to_csv("../data/raw/imigrasi_web_cleaned.csv", index=False)
    print("Data cleaned and saved to imigrasi_web_cleaned.csv")
    return df

# %%
df_web_raw = start_scrape_web()
df_web_clean = clean_faq_web(df_web_raw)
# Out:
# [{'topic': ['Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia'], 'title': ['Kartu Perjalanan Pebisnis APEC', 'Paspor Baru', 'Penggantian Paspor', 'Ubah Data Paspor'], 'link': ['/wni/kartu-perjalanan-pebisnis-apec', '/wni/paspor-baru', '/wni/ganti-paspor', '/wni/rubah-paspor']}, {'topic': ['Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing'], 'title': ['Daftar Subjek VoA, BVK & Calling Visa', 'Izin Tinggal Keimigrasian', 'Permohonan Visa Republik Indonesia'], 'link': ['/wna/daftar-negara-voa-bvk-calling-visa', '/wna/izin-tinggal-keimigrasian', '/wna/permohonan-visa-republik-indonesia']}, {'topic': ['Regulasi UU Imigrasi'], 'title': ['Regulasi UU Imigrasi'], 'link': ['/uu_imigrasi']}]
# 5 topics extracted from https://www.imigrasi.go.id/wni/paspor-baru/masyarakat-umum
# 5 topics extracted from https://www.imigrasi.go.id/wni/paspor-baru/anak-dibawah-17-tahun
# 5 topics extracted from https://www.imigrasi.go.id/wni/paspor-baru/anak-dwikenegaraan
# 5 topics extracted from https://www.imigrasi.go.id/wni/paspor-baru/calon-pekerja-migran-indonesia
# 5 topics extracted from https://www.imigrasi.go.id/wni/paspor-baru/haji-umroh
# 5 topics extracted from https://www.imigrasi.go.id/wni/paspor-baru/di-luar-negeri
# 5 topics extracted from https://www.imigrasi.go.id/wni/ganti-paspor/paspor-masih-ada
# 5 topics extracted from https://www.imigrasi.go.id/wni/ganti-paspor/paspor-rusak
# 5 topics extracted from https://www.imigrasi.go.id/wni/ganti-paspor/paspor-hilang
# 5 topics extracted from https://www.imigrasi.go.id/wni/ganti-paspor/di-luar-negeri-2
# 1 topics extracted from https://www.imigrasi.go.id/wna/daftar-negara-voa-bvk-calling-visa/daftar-negara-subjek-visa-on-arrival?golden_visa=0&all=1
# 1 topics extracted from https://www.imigrasi.go.id/wna/daftar-negara-voa-bvk-calling-visa/daftar-negara-bebas-visa-kunjungan?golden_visa=0&all=1
# 1 topics extracted from https://www.imigrasi.go.id/wna/daftar-negara-voa-bvk-calling-visa/daftar-negara-calling-visa?golden_visa=0&all=1
# 3 topics extracted from https://www.imigrasi.go.id/wna/daftar-negara-voa-bvk-calling-visa/titik-masuk-bagi-pemegang-e-voa?golden_visa=0&all=1
# 7 topics extracted from https://www.imigrasi.go.id/wna/izin-tinggal-keimigrasian/izin-tinggal-terbatas-perairan?golden_visa=0&all=1
# 7 topics extracted from https://www.imigrasi.go.id/wna/izin-tinggal-keimigrasian/perpanjangan-izin-tinggal-tetap?golden_visa=0&all=1
# 7 topics extracted from https://www.imigrasi.go.id/wna/izin-tinggal-keimigrasian/perpanjangan-izin-tinggal-terbatas-2?golden_visa=0&all=1
# 7 topics extracted from https://www.imigrasi.go.id/wna/izin-tinggal-keimigrasian/izin-tinggal-kunjungan-menjadi-izin-tinggal-terbatas?golden_visa=0&all=1
# 7 topics extracted from https://www.imigrasi.go.id/wna/izin-tinggal-keimigrasian/izin-tinggal-terbatas-menjadi-izin-tinggal-tetap?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/izin-tinggal-keimigrasian/perpanjangan-izin-tinggal-kunjungan-2?golden_visa=0&all=1
# 6 topics extracted from https://www.imigrasi.go.id/wna/izin-tinggal-keimigrasian/pelaporan-itap?golden_visa=0&all=1
# 8 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-b1?golden_visa=0&all=1
# 8 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-a1?golden_visa=0&all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-beberapa-kali-perjalanan-indeks-d1?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-indeks-c1?golden_visa=0&all=1
# 5 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c6b?golden_visa=0&all=1
# 8 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-a2?golden_visa=0&all=1
# 8 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-a3?all=1
# 8 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-a37?all=1
# 8 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-a36?all=1
# 8 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-a4?golden_visa=0&all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-beberapa-kali-perjalanan-indeks-d17?golden_visa=0&all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-beberapa-kali-perjalanan-indeks-d2?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-beberapa-kali-perjalanan-indeks-d3?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-beberapa-kali-perjalanan-indeks-d14?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-beberapa-kali-perjalanan-indeks-d12?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-beberapa-kali-perjalanan-indeks-d4?all=1
# 8 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-b2?golden_visa=0&all=1
# 8 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-f2?all=1
# 8 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-b3?all=1
# 8 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-f3?all=1
# 8 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-b4?all=1
# 8 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-f4?all=1
# 8 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-f1?golden_visa=0&all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c8a?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c17?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-13?all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c2?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c5?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c8?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c6?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c15?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c19?golden_visa=0&all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c20?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c6a?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c16?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c10?all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c10a?golden_visa=0&all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c21?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c7a?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c7?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c7b?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c11?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c3?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c8b?all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c9b?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c9a?golden_visa=0&all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c22?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c22a?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c22b?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c14?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c12?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c9?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c4?all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-kunjungan-satu-kali-perjalanan-indeks-c18?all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e32d?golden_visa=0&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e32c?golden_visa=0&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e33e?golden_visa=1&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e32a?golden_visa=1&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e31b-2?golden_visa=1&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e35?golden_visa=0&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e35a?golden_visa=0&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e33?golden_visa=1&all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e28c?golden_visa=1&all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e28b?golden_visa=1&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e28d?golden_visa=1&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e28f?golden_visa=1&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e31e?golden_visa=1&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e31f?golden_visa=0&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e31c?golden_visa=0&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e31d?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e23a-2?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e26?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-untuk-bekerja-di-bidang-agama-indeks-e23w?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e24c?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e24d?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e24?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e24b?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23h?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23j?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e24f?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e24a?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23g?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23b?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23d?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23k?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23l?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e24e?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23i?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23c?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23f?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23e?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23m?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23r?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23u?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23s?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e25b?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23o?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23q?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23p?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e25a?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e25?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e25e?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e25d?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23t?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23v?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/visa-tinggal-terbatas-indeks-e23n?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e27?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e25f?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e25c?golden_visa=0&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e31b?golden_visa=1&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e31a?golden_visa=0&all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e33f?golden_visa=1&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e29?golden_visa=0&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e30?golden_visa=0&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e30a?golden_visa=0&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e30e?golden_visa=0&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e30b?golden_visa=0&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e30d?golden_visa=0&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e30c?golden_visa=0&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e34?golden_visa=0&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e33a?golden_visa=1&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e33b?golden_visa=1&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e31h?golden_visa=1&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e31g?golden_visa=0&all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e33g?golden_visa=0&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e28e?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e28?golden_visa=0&all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e28a?golden_visa=0&all=1
# 9 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e31?golden_visa=0&all=1
# 10 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e32?golden_visa=1&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e33c?golden_visa=1&all=1
# 11 topics extracted from https://www.imigrasi.go.id/wna/permohonan-visa-republik-indonesia/klasifikasi-visa-tinggal-terbatas-indeks-e33d?golden_visa=1&all=1
# 2 topics extracted from https://www.imigrasi.go.id/uu_imigrasi/bab-1-ketentuan-umum
# 5 topics extracted from https://www.imigrasi.go.id/uu_imigrasi/bab-2-pelaksanaan-fungsi-keimigrasian
# 16 topics extracted from https://www.imigrasi.go.id/uu_imigrasi/bab-3-masuk-dan-keluar-wilayah-indonesia
# 10 topics extracted from https://www.imigrasi.go.id/uu_imigrasi/bab-4-dokumen-perjalanan-republik-indonesia
# 32 topics extracted from https://www.imigrasi.go.id/uu_imigrasi/bab-5
# 9 topics extracted from https://www.imigrasi.go.id/uu_imigrasi/bab-6-pengawasan-keimigrasian
# 6 topics extracted from https://www.imigrasi.go.id/uu_imigrasi/bab-7-tindakan-administratif-keimigrasian
# 10 topics extracted from https://www.imigrasi.go.id/uu_imigrasi/bab-8-rumah-detensi-imigrasi-dan-ruang-detensi-imigrasi
# 13 topics extracted from https://www.imigrasi.go.id/uu_imigrasi/bab-9-pencegahan-dan-penangkalan
# 9 topics extracted from https://www.imigrasi.go.id/uu_imigrasi/bab-10-penyidikan
# 24 topics extracted from https://www.imigrasi.go.id/uu_imigrasi/bab-11-ketentuan-pidana
# 2 topics extracted from https://www.imigrasi.go.id/uu_imigrasi/bab-12-biaya
# 2 topics extracted from https://www.imigrasi.go.id/uu_imigrasi/bab-13-ketentuan-lain-lain
# 1 topics extracted from https://www.imigrasi.go.id/uu_imigrasi/bab-14-ketentuan-peralihan
# 4 topics extracted from https://www.imigrasi.go.id/uu_imigrasi/bab-15-penutup
# [{'topic': ['Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia'], 'category': ['Paspor Baru', 'Paspor Baru', 'Paspor Baru', 'Paspor Baru', 'Paspor Baru'], 'question': ['Paspor Baru Masyarakat Umum Informasi Umum', 'Paspor Baru Masyarakat Umum Persyaratan', 'Paspor Baru Masyarakat Umum Prosedur', 'Paspor Baru Masyarakat Umum Mekanisme Penerbitan', 'Paspor Baru Masyarakat Umum Biaya'], 'answer_link': ['https://www.imigrasi.go.id/wni/paspor-baru/masyarakat-umum', 'https://www.imigrasi.go.id/wni/paspor-baru/masyarakat-umum', 'https://www.imigrasi.go.id/wni/paspor-baru/masyarakat-umum', 'https://www.imigrasi.go.id/wni/paspor-baru/masyarakat-umum', 'https://www.imigrasi.go.id/wni/paspor-baru/masyarakat-umum'], 'answer': ['Permohonan paspor biasa dapat diajukan oleh warga negara Indonesia, baik di dalam maupun luar wilayah Indonesia.Paspor biasa terdiri atas paspor biasa elektronik (e-paspor) dan paspor biasa nonelektronik.Paspor biasa diterbitkan dengan menggunakan Sistem Informasi Manajemen Keimigrasian.Permohonan paspor biasa dapat diajukan secara manual atau elektronik dengan melampirkan dokumen kelengkapan persyaratan.', 'Kartu tanda penduduk (KTP) yang masih berlaku atau surat keterangan pindah ke luar negeriKartu keluarga (KK)Dokumen berupa akta kelahiran, akta perkawinan, buku nikah, ijazah, atau surat baptis*Surat pewarganegaraan Indonesia bagi Orang Asing yang memperoleh kewarganegaraan Indonesia atau penyampaian pernyataan untuk memilih kewarganegaraan sesuai dengan ketentuan peraturan perundang-undanganSurat penetapan ganti nama (bagi yang telah mengganti nama) dari pejabat yang berwenangCatatan:*Nama, tempat dan tanggal lahir, serta nama orang tua harus tercantum dalam dokumen. Jika tidak, Anda dapat melampirkan surat keterangan dari instansi yang berwenang.', 'Lakukan pendaftaran melalui aplikasi M-Paspor yang dapat diunduh melalui App Store atau Google Play. Permohonan manual dapat Anda lakukan dengan cara berikut.Isi data di aplikasi yang disediakan pada loket permohonan dan lampirkan dokumen kelengkapan persyaratan.Tunggu Pejabat Imigrasi memeriksa dokumen kelengkapan persyaratan.Dapatkan tanda terima permohonan dan kode pembayaran dari Pejabat Imigrasi setelah dokumen persyaratan dinyatakan lengkap.Jika dokumen persyaratan dinyatakan belum lengkap, terima dokumen permohonan yang dikembalikan Pejabat Imigrasi. Permohonan dianggap ditarik kembali.', 'Pemeriksaan kelengkapan dan keabsahan persyaratanPembayaran biaya pasporPengambilan foto dan sidik jariWawancaraVerifikasiAdjudikasi', 'Paspor biasa nonelektronik 48 halaman: Rp350.000Paspor biasa elektronik 48 halaman: Rp650.000Layanan percepatan paspor*(selesai pada hari yang sama): Rp1.000.000Catatan:*Biaya layanan percepatan di luar penerbitan paspor.']}, {'topic': ['Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia'], 'category': ['Paspor Baru', 'Paspor Baru', 'Paspor Baru', 'Paspor Baru', 'Paspor Baru'], 'question': ['Paspor Baru Anak di bawah 17 Tahun Informasi Umum', 'Paspor Baru Anak di bawah 17 Tahun Persyaratan', 'Paspor Baru Anak di bawah 17 Tahun Prosedur', 'Paspor Baru Anak di bawah 17 Tahun Mekanisme Pengesahan', 'Paspor Baru Anak di bawah 17 Tahun Biaya'], 'answer_link': ['https://www.imigrasi.go.id/wni/paspor-baru/anak-dibawah-17-tahun', 'https://www.imigrasi.go.id/wni/paspor-baru/anak-dibawah-17-tahun', 'https://www.imigrasi.go.id/wni/paspor-baru/anak-dibawah-17-tahun', 'https://www.imigrasi.go.id/wni/paspor-baru/anak-dibawah-17-tahun', 'https://www.imigrasi.go.id/wni/paspor-baru/anak-dibawah-17-tahun'], 'answer': ['Permohonan paspor biasa dapat diajukan oleh warga negara Indonesia, baik di dalam maupun luar wilayah Indonesia.Paspor biasa terdiri atas paspor biasa elektronik (e-paspor) dan paspor biasa nonelektronik.Paspor biasa diterbitkan dengan menggunakan Sistem Informasi Manajemen Keimigrasian.Perm ...
# #############################
# {'topic': ['Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Indonesia', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warga Negara Asing', 'Warg ...
# Data cleaned and saved to imigrasi_web_cleaned.csv

# %% [markdown]
# Combine Dataset

# %%
df_faq_clean.head()
# Out:
#   topic  category                                           question  \
# 0   FAQ  M-Paspor  Apa yang harus saya lakukan jika aplikasi M-Pa...
# 1   FAQ  M-Paspor  Apa yang harus saya lakukan jika tidak bisa lo...
# 2   FAQ  M-Paspor  Apa yang harus saya lakukan jika tidak bisa me...
# 3   FAQ  M-Paspor  Bagaimana Cara Menutup Akun pada Aplikasi M-Pa...
# 4   FAQ  M-Paspor  Bagaimana caranya untuk mendapatkan kuota pada...
#
#                                          answer_link  \
# 0  https://www.imigrasi.go.id/faq/m-paspor/apa-ya...
# 1  https://www.imigrasi.go.id/faq/m-paspor/apa-ya...
# 2  https://www.imigrasi.go.id/faq/m-paspor/apa-ya...
# 3  https://www.imigrasi.go.id/faq/m-paspor/bagaim...
# 4  https://www.imigrasi.go.id/faq/m-paspor/bagaim...
#
#                                               answer type
# 0  Jika mengalami Request Timed Out (RTO) silakan...  faq
# 1  Apabila tidak dapat login M-Paspor, harap mema...  faq
# 2  Silakan menunjukkan QR Code dan bukti bayar ya...  faq
# 3  Sebelum menghapus atau menutup akun M-Paspor, ...  faq
# 4  Kuota yang terdapat pada aplikasi M-Paspor mer...  faq

# %%
df_web_clean.head()
# Out:
#                     topic     category  \
# 0  Warga Negara Indonesia  Paspor Baru
# 1  Warga Negara Indonesia  Paspor Baru
# 2  Warga Negara Indonesia  Paspor Baru
# 3  Warga Negara Indonesia  Paspor Baru
# 4  Warga Negara Indonesia  Paspor Baru
#
#                                            question  \
# 0        Paspor Baru Masyarakat Umum Informasi Umum
# 1           Paspor Baru Masyarakat Umum Persyaratan
# 2              Paspor Baru Masyarakat Umum Prosedur
# 3  Paspor Baru Masyarakat Umum Mekanisme Penerbitan
# 4                 Paspor Baru Masyarakat Umum Biaya
#
#                                          answer_link  \
# 0  https://www.imigrasi.go.id/wni/paspor-baru/mas...
# 1  https://www.imigrasi.go.id/wni/paspor-baru/mas...
# 2  https://www.imigrasi.go.id/wni/paspor-baru/mas...
# 3  https://www.imigrasi.go.id/wni/paspor-baru/mas...
# 4  https://www.imigrasi.go.id/wni/paspor-baru/mas...
#
#                                               answer type
# 0  Permohonan paspor biasa dapat diajukan oleh wa...  web
# 1  Kartu tanda penduduk (KTP) yang masih berlaku ...  web
# 2  Lakukan pendaftaran melalui aplikasi M-Paspor ...  web
# 3  Pemeriksaan kelengkapan dan keabsahan persyara...  web
# 4  Paspor biasa nonelektronik 48 halaman: Rp350.0...  web

# %%
df_combined = pd.concat([df_faq_clean, df_web_clean], ignore_index=True)
df_combined.head()
# Out:
#   topic  category                                           question  \
# 0   FAQ  M-Paspor  Apa yang harus saya lakukan jika aplikasi M-Pa...
# 1   FAQ  M-Paspor  Apa yang harus saya lakukan jika tidak bisa lo...
# 2   FAQ  M-Paspor  Apa yang harus saya lakukan jika tidak bisa me...
# 3   FAQ  M-Paspor  Bagaimana Cara Menutup Akun pada Aplikasi M-Pa...
# 4   FAQ  M-Paspor  Bagaimana caranya untuk mendapatkan kuota pada...
#
#                                          answer_link  \
# 0  https://www.imigrasi.go.id/faq/m-paspor/apa-ya...
# 1  https://www.imigrasi.go.id/faq/m-paspor/apa-ya...
# 2  https://www.imigrasi.go.id/faq/m-paspor/apa-ya...
# 3  https://www.imigrasi.go.id/faq/m-paspor/bagaim...
# 4  https://www.imigrasi.go.id/faq/m-paspor/bagaim...
#
#                                               answer type
# 0  Jika mengalami Request Timed Out (RTO) silakan...  faq
# 1  Apabila tidak dapat login M-Paspor, harap mema...  faq
# 2  Silakan menunjukkan QR Code dan bukti bayar ya...  faq
# 3  Sebelum menghapus atau menutup akun M-Paspor, ...  faq
# 4  Kuota yang terdapat pada aplikasi M-Paspor mer...  faq

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1582 entries, 0 to 1581
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   topic        1582 non-null   object
#  1   category     1582 non-null   object
#  2   question     1582 non-null   object
#  3   answer_link  1582 non-null   object
#  4   answer       1582 non-null   object
#  5   type         1582 non-null   object
# dtypes: object(6)
# memory usage: 74.3+ KB
# Data cleaned and saved to imigrasi_combined_topics.csv

# %%
df_combined['full_context'] = 'Question: ' + df_combined['question'] + '; Answer: ' + df_combined['answer'] + '; Reference: ' + df_combined['answer_link']
df_combined = df_combined.dropna()

df_combined.to_csv('../data/imigrasi_combined_topics_full_context.csv', index=False)
